# %% [markdown]
# ## Mixed-Integer Linear Program (MILP) using the CBC solver (Coin-or branch and cut)

# %% [markdown]
# ### Interpreting the Output :
# For each player, a performance score is computed — derived from pairwise interactions. In the output, the final objective value represents the sum of selected players’ performance contributions (multiplied by 100) for numerical stability during optimization.
#
# Although the absolute magnitude of the score may appear lower than expected. The formulation is theoretically sound, as evidenced by the solver reaching an optimal solution without invoking any branching, cutting planes, or node expansion. This means:
#
#     * The problem was well-constrained and solvable using heuristics.
#
#     * The feasibility pump found a valid integer solution immediately.
#
#     * No time was spent exploring alternate solutions via branch-and-bound.
#
# The solver output consists of two key components:
#
#     * Objective Function Value:
#     The cumulative performance score for the selected team.
#     This value is what the model seeks to maximize, subject to all constraints.
#
#     * Selected Playing XI:
#     The optimal team composition as determined by the solver — adhering to role requirements (batsmen, bowlers, all-rounders, etc.) and maximizing the team’s overall performance potential under the given model.
# NOTE : Ignore the warning.

# %%
# !pip install pulp

# %%
import pandas as pd
from pulp import LpMaximize, LpProblem, LpVariable, lpSum

# Function to compute bowler performance score with smoothing
def bowler_score(bowler, opposition_batsmen, stats, min_balls=20, wicket_value=20, dot_value=5, boundary_penalty=10, alpha=0.5):
    scores = []
    overall_stats = stats[stats['bowler'] == bowler]
    n_o = overall_stats['balls'].sum() if not overall_stats.empty else 0
    w_o = overall_stats['is_wicket'].sum() if not overall_stats.empty else 0
    r_o = overall_stats['Runs'].sum() if not overall_stats.empty else 0
    d_o = overall_stats['derived_dot_balls'].sum() if not overall_stats.empty else 0
    b_o = overall_stats['derived_boundaries'].sum() if not overall_stats.empty else 0

    for t in opposition_batsmen:
        pair_stats = stats[(stats['bowler'] == bowler) & (stats['batsman'] == t)]
        if not pair_stats.empty:
            n = pair_stats['balls'].iloc[0]
            w = pair_stats['is_wicket'].iloc[0]
            r = pair_stats['Runs'].iloc[0]
            d = pair_stats['derived_dot_balls'].iloc[0]
            b = pair_stats['derived_boundaries'].iloc[0]
            if n >= min_balls:
                e = ((w / n) * wicket_value - (r / n) + (d / n) * dot_value - (b / n) * boundary_penalty) * 100
            else:
                n_smooth = n + alpha * n_o
                w_smooth = w + alpha * w_o
                r_smooth = r + alpha * r_o
                d_smooth = d + alpha * d_o
                b_smooth = b + alpha * b_o
                e = ((w_smooth / n_smooth) * wicket_value - (r_smooth / n_smooth) + (d_smooth / n_smooth) * dot_value - (b_smooth / n_smooth) * boundary_penalty) * 100
            print(f"Bowler {bowler} vs Batsman {t}: {n} balls, {w} wickets, {r} runs, {d} dot balls, {b} boundaries, score = {e}")
        else:
            if n_o > 0:
                e = ((w_o / n_o) * wicket_value - (r_o / n_o) + (d_o / n_o) * dot_value - (b_o / n_o) * boundary_penalty) * 100
                print(f"Bowler {bowler} vs Batsman {t}: Using overall stats, score = {e}")
            else:
                e = 10  # Default score
                print(f"Bowler {bowler} vs Batsman {t}: No data, default score = {e}")
        scores.append(e)
    return sum(scores) / len(opposition_batsmen) if scores else 0

# Function to compute batsman performance score with smoothing
def batsman_score(batsman, opposition_bowlers, stats, min_balls=20, boundary_value=0.5, beta=0.5):
    scores = []
    overall_stats = stats[stats['batsman'] == batsman]
    n_o = overall_stats['balls'].sum() if not overall_stats.empty else 0
    r_o = overall_stats['Runs'].sum() if not overall_stats.empty else 0
    b_o = overall_stats['derived_boundaries'].sum() if not overall_stats.empty else 0

    for o in opposition_bowlers:
        pair_stats = stats[(stats['batsman'] == batsman) & (stats['bowler'] == o)]
        if not pair_stats.empty:
            n = pair_stats['balls'].iloc[0]
            r = pair_stats['Runs'].iloc[0]
            b = pair_stats['derived_boundaries'].iloc[0]
            if n >= min_balls:
                e = ((r / n) + (b / n) * boundary_value) * 100
            else:
                n_smooth = n + beta * n_o
                r_smooth = r + beta * r_o
                b_smooth = b + beta * b_o
                e = ((r_smooth / n_smooth) + (b_smooth / n_smooth) * boundary_value) * 100
            print(f"Batsman {batsman} vs Bowler {o}: {n} balls, {r} runs, {b} boundaries, score = {e}")
        else:
            if n_o > 0:
                e = ((r_o / n_o) + (b_o / n_o) * boundary_value) * 100
                print(f"Batsman {batsman} vs Bowler {o}: Using overall stats, score = {e}")
            else:
                e = 10  # Default score
                print(f"Batsman {batsman} vs Bowler {o}: No data, default score = {e}")
        scores.append(e)
    return sum(scores) / len(opposition_bowlers) if scores else 0

# Main function to select the playing eleven
def select_playing_eleven(opposition_team, squad, data_file='final.csv'):
    try:
        df = pd.read_csv(data_file)
        df['Stadium_Type'] = df['Stadium_Type'].fillna('Unknown')
        stadium_order = {'Small': 1, 'Medium': 2, 'Large': 3, 'Unknown': 4}
        df['Stadium_Rank'] = df['Stadium_Type'].map(stadium_order)
        df = df.sort_values(by='Stadium_Rank').drop(columns=['Stadium_Rank'])

        if df.empty:
            raise ValueError("Dataset is empty.")
        print(f"Total dataset size: {len(df)} rows")

        # Compute historical statistics with derived metrics
        stats = df.groupby(['bowler', 'batsman']).apply(
            lambda g: pd.Series({
                'Runs': g['Runs'].sum(),
                'is_wicket': g['is_wicket'].sum(),
                'balls': g['ball'].count(),
                'derived_dot_balls': ((g['Runs'] == 0) & (g['is_wicket'] == False)).sum(),
                'derived_boundaries': (g['Runs'] >= 4).sum()
            })
        ).reset_index()

        if stats.empty:
            raise ValueError("No bowler-batsman pairs found after aggregation.")
        print(f"Number of bowler-batsman pairs: {len(stats)}")
        print(f"Pairs with <20 balls: {len(stats[stats['balls'] < 20])}")
        print(f"Sparsity percentage (<20 balls): {len(stats[stats['balls'] < 20]) / len(stats) * 100:.2f}%")

        # Check player data availability
        squad_names = [p['name'] for p in squad]
        opposition_names = [p['name'] for p in opposition_team]
        stats_bowlers = set(stats['bowler'])
        stats_batsmen = set(stats['batsman'])
        missing_squad = [name for name in squad_names if name not in stats_bowlers and name not in stats_batsmen]
        missing_opposition = [name for name in opposition_names if name not in stats_bowlers and name not in stats_batsmen]
        print(f"Missing squad players in stats: {missing_squad}")
        print(f"Missing opposition players in stats: {missing_opposition}")

        # Separate opposition batsmen and bowlers
        opposition_batsmen = [p['name'] for p in opposition_team if p['role'] in ['batsman', 'wicket-keeper']]
        opposition_bowlers = [p['name'] for p in opposition_team if p['role'] == 'bowler']
        print(f"Opposition Batsmen: {opposition_batsmen}")
        print(f"Opposition Bowlers: {opposition_bowlers}")

        # Compute performance scores
        player_scores = {}
        for player in squad:
            name = player['name']
            role = player['role']
            if role == 'bowler':
                score = bowler_score(name, opposition_batsmen, stats)
            elif role in ['batsman', 'wicket-keeper']:
                score = batsman_score(name, opposition_bowlers, stats)
            elif role == 'all-rounder':
                bat_score = batsman_score(name, opposition_bowlers, stats)
                bowl_score = bowler_score(name, opposition_batsmen, stats)
                score = (bat_score + bowl_score) / 2  # Average for all-rounders
            player_scores[name] = score
            print(f"Player: {name} ({role}) score is {score}")

        # Set up the optimization problem
        prob = LpProblem("Playing_Eleven_Selection", LpMaximize)
        x = {p['name']: LpVariable(f"x_{p['name']}", 0, 1, 'Binary') for p in squad}

        # Objective
        prob += lpSum([x[p['name']] * player_scores[p['name']] for p in squad])

        # Constraints
        prob += lpSum([x[p['name']] for p in squad]) == 11
        batsmen = [p['name'] for p in squad if p['role'] == 'batsman']
        bowlers = [p['name'] for p in squad if p['role'] == 'bowler']
        all_rounders = [p['name'] for p in squad if p['role'] == 'all-rounder']
        wicket_keepers = [p['name'] for p in squad if p['role'] == 'wicket-keeper']
        prob += lpSum([x[p] for p in batsmen]) >= 3
        prob += lpSum([x[p] for p in batsmen]) <= 6
        prob += lpSum([x[p] for p in bowlers]) >= 3
        prob += lpSum([x[p] for p in bowlers]) <= 6
        prob += lpSum([x[p] for p in all_rounders]) >= 1
        prob += lpSum([x[p] for p in all_rounders]) <= 4
        prob += lpSum([x[p] for p in wicket_keepers]) == 1

        prob.solve()

        # Check solver status
        status = prob.status
        print(f"Solver Status: {status} (1=Optimal, 0=Not Solved, -1=Infeasible)")
        if status != 1:
            raise ValueError("Optimization failed to find an optimal solution.")

        # Extract selected players
        selected_players = [p for p in squad if x[p['name']].value() == 1]
        return selected_players

    except Exception as e:
        print(f"Error: {e}")
        return None

if __name__ == "__main__":
    # Opposition team (11 players)
    opposition_team = [
        {'name': 'Virat Kohli', 'role': 'batsman'},
        {'name': 'Shubman Gill', 'role': 'batsman'},
        {'name': 'Suryakumar Yadav', 'role': 'batsman'},
        {'name': 'Tilak Varma', 'role': 'batsman'},
        {'name': 'Heinrich Klaasen', 'role': 'batsman'},
        {'name': 'Ravindra Jadeja', 'role': 'all-rounder'},
        {'name': 'Jasprit Bumrah', 'role': 'bowler'},
        {'name': 'Yuzvendra Chahal', 'role': 'bowler'},
        {'name': 'Arshdeep Singh', 'role': 'bowler'},
        {'name': 'Trent Boult', 'role': 'bowler'},
        {'name': 'KL Rahul', 'role': 'wicket-keeper'}
    ]

    # Squad (15 players)
    squad = [
        {'name': 'Rohit Sharma', 'role': 'batsman'},
        {'name': 'Faf du Plessis', 'role': 'batsman'},
        {'name': 'Ruturaj Gaikwad', 'role': 'batsman'},
        {'name': 'Sanju Samson', 'role': 'batsman'},
        {'name': 'Jos Buttler', 'role': 'batsman'},
        {'name': 'Pat Cummins', 'role': 'bowler'},
        {'name': 'Kagiso Rabada', 'role': 'bowler'},
        {'name': 'Rashid Khan', 'role': 'bowler'},
        {'name': 'Sunil Narine', 'role': 'bowler'},
        {'name': 'Mohammed Shami', 'role': 'bowler'},
        {'name': 'Andre Russell', 'role': 'all-rounder'},
        {'name': 'Glenn Maxwell', 'role': 'all-rounder'},
        {'name': 'Hardik Pandya', 'role': 'all-rounder'},
        {'name': 'MS Dhoni', 'role': 'wicket-keeper'},
        {'name': 'Rishabh Pant', 'role': 'wicket-keeper'}
    ]

    selected_team = select_playing_eleven(opposition_team, squad)
    if selected_team:
        print("\nSelected Playing Eleven:")
        for player in selected_team:
            print(f"{player['name']} ({player['role']})")
# Out:
# Total dataset size: 143823 rows
# Number of bowler-batsman pairs: 15991
# Pairs with <20 balls: 14300
# Sparsity percentage (<20 balls): 89.43%
# Missing squad players in stats: []
# Missing opposition players in stats: []
# Opposition Batsmen: ['Virat Kohli', 'Shubman Gill', 'Suryakumar Yadav', 'Tilak Varma', 'Heinrich Klaasen', 'KL Rahul']
# Opposition Bowlers: ['Jasprit Bumrah', 'Yuzvendra Chahal', 'Arshdeep Singh', 'Trent Boult']
# Batsman Rohit Sharma vs Bowler Jasprit Bumrah: 6 balls, 7 runs, 0 boundaries, score = 143.56382978723403
# Batsman Rohit Sharma vs Bowler Yuzvendra Chahal: 29 balls, 34 runs, 2 boundaries, score = 120.6896551724138
# Batsman Rohit Sharma vs Bowler Arshdeep Singh: 14 balls, 17 runs, 2 boundaries, score = 143.5296191819464
# Batsman Rohit Sharma vs Bowler Trent Boult: 20 balls, 19 runs, 1 boundaries, score = 97.5
# Player: Rohit Sharma (batsman) score is 126.32077603539855
# Batsman Faf du Plessis vs Bowler Jasprit Bumrah: 41 balls, 61 runs, 8 boundaries, score = 158.53658536585365
# Batsman Faf du Plessis vs Bowler Yuzvendra Chahal: 35 balls, 32 runs, 1 boundaries, score = 92.85714285714285
# Batsman Faf du Plessis vs Bowler Arshdeep Singh: 46 balls, 67 runs, 8 boundaries, score = 154.34782608695653
# Batsman Faf du Plessis vs Bowler Trent Boult: 87 balls, 92 runs, 15 boundaries, score = 114.36781609195404
# Player: Faf du Plessis (batsman) score is 130.02734260047677
# Batsman Ruturaj Gaikwad vs Bowler Jasprit Bumrah: 18 balls, 31 runs, 4 boundaries, score = 149.02080783353733
# Batsman Ruturaj Gaikwad vs Bowler Yuzvendra Chahal: 41 balls, 47 runs, 6 boundaries, score = 121.95121951219512
# Batsman Ruturaj Gaikwad vs Bowler Arshdeep Singh: 38 balls, 43 runs, 7 boundaries, score = 122.36842105263158
# Batsman Ruturaj Gaikwad vs Bowler Trent Boult: 27 balls, 25 runs, 4 boundaries, score = 100.0
# Player: Ruturaj Gaikwad (batsman) score is 123.335112099591
# Batsman Sanju Samson vs Bowler Jasprit Bumrah: 50 balls, 43 runs, 5 boundaries, score = 91.0
# Batsman Sanju Samson vs Bowler Yuzvendra Chahal: 38 balls, 41 runs, 4 boundaries, score = 113.1578947368421
# Batsman Sanju Samson vs Bowler Arshdeep Singh: 39 balls, 72 runs, 12 boundaries, score = 200.0
# Batsman Sanju Samson vs Bowler Trent Boult: 29 balls, 35 runs, 4 boundaries, score = 127.58620689655172
# Player: Sanju Samson (batsman) score is 132.93602540834846
# Batsman Jos Buttler vs Bowler Jasprit Bumrah: 67 balls, 65 runs, 10 boundaries, score = 104.4776119402985
# Batsman Jos Buttler vs Bowler Yuzvendra Chahal: 30 balls, 33 runs, 3 boundaries, score = 115.00000000000001
# Batsman Jos Buttler vs Bowler Arshdeep Singh: 17 balls, 26 runs, 3 boundaries, score = 161.53202176642947
# Batsman Jos Buttler vs Bowler Trent Boult: 21 balls, 25 runs, 4 boundaries, score = 128.57142857142856
# Player: Jos Buttler (batsman) score is 127.39526556953913
# Bowler Pat Cummins vs Batsman Virat Kohli: 19 balls, 0 wickets, 23 runs, 8 dot balls, 3 boundaries, score = -93.89438943894388
# Bowler Pat Cummins vs Batsman Shubman Gill: Using overall stats, score = -94.71890971039178
# Bowler Pat Cummins vs Batsman Suryakumar Yadav: 40 balls, 2 wickets, 46 runs, 18 dot balls, 6 boundaries, score = 60.00000000000001
# Bowler Pat Cummins vs Batsman Tilak Varma: 21 balls, 1 wickets, 33 runs, 5 dot balls, 5 boundaries, score = -180.95238095238096
# Bowler Pat Cummins vs Batsman Heinrich Klaasen: Using overall stats, score = -94.71890971039178
# Bowler Pat Cummins vs Batsman KL Rahul: Using overall stats, score = -94.71890971039178
# Player: Pat Cummins (bowler) score is -83.1672499204167
# Bowler Kagiso Rabada vs Batsman Virat Kohli: 25 balls, 3 wickets, 29 runs, 4 dot balls, 3 boundaries, score = 84.00000000000001
# Bowler Kagiso Rabada vs Batsman Shubman Gill: 55 balls, 2 wickets, 65 runs, 19 dot balls, 8 boundaries, score = -18.181818181818187
# Bowler Kagiso Rabada vs Batsman Suryakumar Yadav: 56 balls, 3 wickets, 88 runs, 17 dot balls, 12 boundaries, score = -112.5
# Bowler Kagiso Rabada vs Batsman Tilak Varma: 5 balls, 0 wickets, 10 runs, 0 dot balls, 1 boundaries, score = -43.53400222965438
# Bowler Kagiso Rabada vs Batsman Heinrich Klaasen: 2 balls, 0 wickets, 1 runs, 1 dot balls, 0 boundaries, score = -40.99552572706933
# Bowler Kagiso Rabada vs Batsman KL Rahul: 21 balls, 2 wickets, 27 runs, 8 dot balls, 4 boundaries, score = 61.904761904761905
# Player: Kagiso Rabada (bowler) score is -11.551097372296661
# Bowler Rashid Khan vs Batsman Virat Kohli: 57 balls, 2 wickets, 70 runs, 15 dot balls, 7 boundaries, score = -43.85964912280702
# Bowler Rashid Khan vs Batsman Shubman Gill: 38 balls, 2 wickets, 31 runs, 13 dot balls, 2 boundaries, score = 142.10526315789474
# Bowler Rashid Khan vs Batsman Suryakumar Yadav: 58 balls, 0 wickets, 87 runs, 16 dot balls, 13 boundaries, score = -236.2068965517241
# Bowler Rashid Khan vs Batsman Tilak Varma: 16 balls, 2 wickets, 19 runs, 3 dot balls, 1 boundaries, score = 35.52537526804862
# Bowler Rashid Khan vs Batsman Heinrich Klaasen: 15 balls, 0 wickets, 18 runs, 4 dot balls, 1 boundaries, score = 33.11874105865522
# Bowler Rashid Khan vs Batsman KL Rahul: 47 balls, 3 wickets, 40 runs, 15 dot balls, 3 boundaries, score = 138.29787234042553
# Player: Rashid Khan (bowler) score is 11.496784358415498
# Bowler Sunil Narine vs Batsman Virat Kohli: 82 balls, 2 wickets, 97 runs, 24 dot balls, 9 boundaries, score = -32.92682926829269
# Bowler Sunil Narine vs Batsman Shubman Gill: 6 balls, 1 wickets, 8 runs, 1 dot balls, 1 boundaries, score = -5.6471413539108894
# Bowler Sunil Narine vs Batsman Suryakumar Yadav: 59 balls, 0 wickets, 72 runs, 18 dot balls, 8 boundaries, score = -105.08474576271185
# Bowler Sunil Narine vs Batsman Tilak Varma: 8 balls, 0 wickets, 12 runs, 1 dot balls, 1 boundaries, score = -7.320490367775823
# Bowler Sunil Narine vs Batsman Heinrich Klaasen: 20 balls, 0 wickets, 32 runs, 1 dot balls, 3 boundaries, score = -285.0
# Bowler Sunil Narine vs Batsman KL Rahul: 55 balls, 2 wickets, 83 runs, 17 dot balls, 11 boundaries, score = -123.63636363636363
# Player: Sunil Narine (bowler) score is -93.26926173150916
# Bowler Mohammed Shami vs Batsman Virat Kohli: 64 balls, 5 wickets, 92 runs, 14 dot balls, 14 boundaries, score = -96.875
# Bowler Mohammed Shami vs Batsman Shubman Gill: 36 balls, 3 wickets, 41 runs, 15 dot balls, 6 boundaries, score = 94.44444444444446
# Bowler Mohammed Shami vs Batsman Suryakumar Yadav: 20 balls, 1 wickets, 41 runs, 6 dot balls, 8 boundaries, score = -355.0
# Bowler Mohammed Shami vs Batsman Tilak Varma: 9 balls, 0 wickets, 31 runs, 1 dot balls, 6 boundaries, score = -53.13390313390309
# Bowler Mohammed Shami vs Batsman Heinrich Klaasen: 6 balls, 1 wickets, 4 runs, 1 dot balls, 0 boundaries, score = -43.095238095238095
# Bowler Mohammed Shami vs Batsman KL Rahul: 31 balls, 2 wickets, 29 runs, 17 dot balls, 5 boundaries, score = 148.38709677419354
# Player: Mohammed Shami (bowler) score is -50.8787666684172
# Batsman Andre Russell vs Bowler Jasprit Bumrah: 46 balls, 62 runs, 9 boundaries, score = 144.56521739130434
# Batsman Andre Russell vs Bowler Yuzvendra Chahal: 42 balls, 94 runs, 15 boundaries, score = 241.66666666666666
# Batsman Andre Russell vs Bowler Arshdeep Singh: 19 balls, 37 runs, 6 boundaries, score = 189.7120786516854
# Batsman Andre Russell vs Bowler Trent Boult: 11 balls, 22 runs, 4 boundaries, score = 189.59517045454547
# Bowler Andre Russell vs Batsman Virat Kohli: 52 balls, 1 wickets, 68 runs, 12 dot balls, 6 boundaries, score = -92.3076923076923
# Bowler Andre Russell vs Batsman Shubman Gill: Using overall stats, score = -70.14218009478672
# Bowler Andre Russell vs Batsman Suryakumar Yadav: 22 balls, 3 wickets, 41 runs, 5 dot balls, 7 boundaries, score = -118.18181818181819
# Bowler Andre Russell vs Batsman Tilak Varma: 19 balls, 1 wickets, 29 runs, 5 dot balls, 5 boundaries, score = -72.87128712871285
# Bowler Andre Russell vs Batsman Heinrich Klaasen: 9 balls, 0 wickets, 12 runs, 1 dot balls, 1 boundaries, score = -71.57190635451505
# Bowler Andre Russell vs Batsman KL Rahul: 24 balls, 1 wickets, 38 runs, 3 dot balls, 4 boundaries, score = -179.16666666666666
# Player: Andre Russell (all-rounder) score is 45.33892908434259
# Batsman Glenn Maxwell vs Bowler Jasprit Bumrah: 32 balls, 41 runs, 6 boundaries, score = 137.5
# Batsman Glenn Maxwell vs Bowler Yuzvendra Chahal: 38 balls, 65 runs, 9 boundaries, score = 182.89473684210526
# Batsman Glenn Maxwell vs Bowler Arshdeep Singh: 5 balls, 9 runs, 1 boundaries, score = 166.34877384196184
# Batsman Glenn Maxwell vs Bowler Trent Boult: 25 balls, 36 runs, 6 boundaries, score = 156.0
# Bowler Glenn Maxwell vs Batsman Virat Kohli: 11 balls, 0 wickets, 14 runs, 0 dot balls, 1 boundaries, score = -50.586854460093925
# Bowler Glenn Maxwell vs Batsman Shubman Gill: 10 balls, 1 wickets, 10 runs, 3 dot balls, 1 boundaries, score = -41.52941176470585
# Bowler Glenn Maxwell vs Batsman Suryakumar Yadav: 12 balls, 0 wickets, 12 runs, 1 dot balls, 0 boundaries, score = -46.48711943793907
# Bowler Glenn Maxwell vs Batsman Tilak Varma: 5 balls, 0 wickets, 13 runs, 0 dot balls, 2 boundaries, score = -53.45238095238096
# Bowler Glenn Maxwell vs Batsman Heinrich Klaasen: Using overall stats, score = -46.14457831325299
# Bowler Glenn Maxwell vs Batsman KL Rahul: 13 balls, 1 wickets, 13 runs, 5 dot balls, 1 boundaries, score = -39.602803738317746
# Player: Glenn Maxwell (all-rounder) score is 57.19267644661751
# Batsman Hardik Pandya vs Bowler Jasprit Bumrah: 3 balls, 6 runs, 1 boundaries, score = 158.70457209847595
# Batsman Hardik Pandya vs Bowler Yuzvendra Chahal: 67 balls, 63 runs, 4 boundaries, score = 97.01492537313433
# Batsman Hardik Pandya vs Bowler Arshdeep Singh: 21 balls, 14 runs, 1 boundaries, score = 69.04761904761905
# Batsman Hardik Pandya vs Bowler Trent Boult: 26 balls, 45 runs, 6 boundaries, score = 184.6153846153846
# Bowler Hardik Pandya vs Batsman Virat Kohli: 44 balls, 1 wickets, 57 runs, 13 dot balls, 8 boundaries, score = -118.18181818181819
# Bowler Hardik Pandya vs Batsman Shubman Gill: 12 balls, 3 wickets, 7 runs, 6 dot balls, 1 boundaries, score = -100.9783368273934
# Bowler Hardik Pandya vs Batsman Suryakumar Yadav: 8 balls, 0 wickets, 13 runs, 2 dot balls, 2 boundaries, score = -115.03865073787769
# Bowler Hardik Pandya vs Batsman Tilak Varma: 2 balls, 0 wickets, 7 runs, 0 dot balls, 1 boundaries, score = -115.1665485471297
# Bowler Hardik Pandya vs Batsman Heinrich Klaasen: 4 balls, 0 wickets, 8 runs, 1 dot balls, 1 boundaries, score = -114.2756183745583
# Bowler Hardik Pandya vs Batsman KL Rahul: 47 balls, 1 wickets, 68 runs, 9 dot balls, 7 boundaries, score = -155.31914893617022
# Player: Hardik Pandya (all-rounder) score is 3.759469174747778
# Batsman MS Dhoni vs Bowler Jasprit Bumrah: 60 balls, 60 runs, 5 boundaries, score = 104.16666666666667
# Batsman MS Dhoni vs Bowler Yuzvendra Chahal: 72 balls, 94 runs, 8 boundaries, score = 136.11111111111111
# Batsman MS Dhoni vs Bowler Arshdeep Singh: 16 balls, 21 runs, 3 boundaries, score = 141.9268292682927
# Batsman MS Dhoni vs Bowler Trent Boult: 45 balls, 83 runs, 12 boundaries, score = 197.77777777777777
# Player: MS Dhoni (wicket-keeper) score is 144.99559620596204
# Batsman Rishabh Pant vs Bowler Jasprit Bumrah: 48 balls, 58 runs, 7 boundaries, score = 128.125
# Batsman Rishabh Pant vs Bowler Yuzvendra Chahal: 54 balls, 76 runs, 9 boundaries, score = 149.07407407407408
# Batsman Rishabh Pant vs Bowler Arshdeep Singh: 2 balls, 2 runs, 0 boundaries, score = 160.27183600713013
# Batsman Rishabh Pant vs Bowler Trent Boult: 12 balls, 13 runs, 2 boundaries, score = 159.9160777385159
# Player: Rishabh Pant (wicket-keeper) score is 149.34674695493004
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/nikhil-saxena/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/144f6f6f05f34489b3958c4f8d509c8c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/144f6f6f05f34489b3958c4f8d509c8c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 102 RHS
# At line 111 BOUNDS
# At line 127 ENDATA
# Problem MODEL has 8 rows, 15 columns and 43 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 840.96 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 13 columns (13 integer (13 of which binary)) and 26 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -840.96
# Cbc0038I Before mini branch and bound, 13 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -840.96 - took 0.00 seconds
# Cbc0012I Integer solution of -840.95979 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -840.95979451686, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -840.96 to -840.96
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                840.95979452
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solver Status: 1 (1=Optimal, 0=Not Solved, -1=Infeasible)
#
# Selected Playing Eleven:
# Rohit Sharma (batsman)
# Faf du Plessis (batsman)
# Ruturaj Gaikwad (batsman)
# Sanju Samson (batsman)
# Jos Buttler (batsman)
# Kagiso Rabada (bowler)
# Rashid Khan (bowler)
# Mohammed Shami (bowler)
# Andre Russell (all-rounder)
# Glenn Maxwell (all-rounder)
# Rishabh Pant (wicket-keeper)
# /tmp/ipykernel_594705/859545662.py:88: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   stats = df.groupby(['bowler', 'batsman']).apply(
