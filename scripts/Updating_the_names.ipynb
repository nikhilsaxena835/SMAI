# %%
import os
import pandas as pd

# Path to the main dataset folder
dataset_path = 'dataset'

# Loop through each year folder (2015 to 2024)
for year in range(2015, 2025):
    year_folder = os.path.join(dataset_path, str(year))
    
    if not os.path.isdir(year_folder):
        continue

    # Loop through each CSV file in the folder
    for filename in os.listdir(year_folder):
        if filename.endswith('.csv'):
            file_path = os.path.join(year_folder, filename)

            # Read the CSV file
            try:
                df = pd.read_csv(file_path)
                
                # Check if 'batsman' column exists
                if 'batsman' in df.columns:
                    # Replace the name
                    df['batsman'] = df['batsman'].replace('du Plessis', 'Faf du Plessis')
                    df['batsman'] = df['batsman'].replace('Rawat', 'Anuj Rawat')
                    df['batsman'] = df['batsman'].replace('Padikkal', 'Devdutt Padikkal')
                    df['batsman'] = df['batsman'].replace('Green', 'Cameron Green')
                    df['batsman'] = df['batsman'].replace('Rahul', 'KL Rahul')
                    df['batsman'] = df['batsman'].replace('Ahmed', 'Shahbaz Ahmed')
                    df['batsman'] = df['batsman'].replace('Karthik', 'Dinesh Karthik')
                    df['batsman'] = df['batsman'].replace('JL Denly', 'Joe Denly')
                    df['batsman'] = df['batsman'].replace('JPR Scantlebury-Searles', 'Javon Searles')
                    df['batsman'] = df['batsman'].replace('DJM Short', "D'Arcy Short")
                    df['batsman'] = df['batsman'].replace('Siraj', 'Mohammed Siraj')
                    df['batsman'] = df['batsman'].replace('de Grandhomme', 'Colin de Grandhomme')
                    df['batsman'] = df['batsman'].replace('A Raghuvanshi', 'Angkrish Raghuvanshi')
                    df['batsman'] = df['batsman'].replace('Lomror', 'Mahipal Lomror')
                    df['batsman'] = df['batsman'].replace('R Dhawan', 'Rishi Dhawan')
                    df['batsman'] = df['batsman'].replace('Stoinis', 'Marcus Stoinis')
                    df['batsman'] = df['batsman'].replace('Nitish Kumar', 'Nitish Kumar Reddy')
                    df['batsman'] = df['batsman'].replace('Samson', 'Sanju Samson')
                    df['batsman'] = df['batsman'].replace('van der Dussen', 'Rassie van der Dussen')
                    df['batsman'] = df['batsman'].replace('Jagadeesha Suchith', 'Jagadeesha Suchith')
                    df['batsman'] = df['batsman'].replace('Hetmyer', 'Shimron Hetmyer')
                    df['batsman'] = df['batsman'].replace('Gulbadin Naib', 'Gulbadin Naib')
                    df['batsman'] = df['batsman'].replace('MW Short', 'Matthew Short')
                    df['batsman'] = df['batsman'].replace('de Villiers', 'AB de Villiers')
                    df['batsman'] = df['batsman'].replace('Warner', 'David Warner')
                    df['batsman'] = df['batsman'].replace('M Ashwin', 'Murugan Ashwin')
                    df['batsman'] = df['batsman'].replace('Wanindu Hasaranga', 'Wanindu Hasaranga')
                    df['batsman'] = df['batsman'].replace('Nortje', 'Anrich Nortje')
                    df['batsman'] = df['batsman'].replace('Pooran', 'Nicholas Pooran')
                    df['batsman'] = df['batsman'].replace('Kuldeep', 'Kuldeep Sen')
                    df['batsman'] = df['batsman'].replace('J Fraser-McGurk', 'Jake Fraser-McGurk')
                    df['batsman'] = df['batsman'].replace('Shahrukh Khan', 'M Shahrukh Khan')
                    df['batsman'] = df['batsman'].replace('Shaw', 'Prithvi Shaw')
                    df['batsman'] = df['batsman'].replace('S Dhawan', 'Shikhar Dhawan')
                    df['batsman'] = df['batsman'].replace('Topley', 'Reece Topley')
                    df['batsman'] = df['batsman'].replace('Badoni', 'Ayush Badoni')
                    df['batsman'] = df['batsman'].replace('Buttler', 'Jos Buttler')
                    df['batsman'] = df['batsman'].replace('de Kock', 'Quinton de Kock')
                    df['batsman'] = df['batsman'].replace('SS Prabhudessai', 'Suyash Prabhudessai')
                    df['batsman'] = df['batsman'].replace('Jurel', 'Dhruv Jurel')
                    df['batsman'] = df['batsman'].replace('M Nabi', 'Mohammad Nabi')
                    df['batsman'] = df['batsman'].replace('Kohli', 'Virat Kohli')
                    df['batsman'] = df['batsman'].replace('Jaiswal', 'Yashasvi Jaiswal')
                    df['batsman'] = df['batsman'].replace('Ray Barman', 'Prayas Ray Barman')
                    df['batsman'] = df['batsman'].replace('Pandey', 'Manish Pandey')
                    df['batsman'] = df['batsman'].replace('Karan', 'Karn Sharma')
                    df['batsman'] = df['batsman'].replace('B Sai Sudharsan', 'Sai Sudharsan')
                    df['batsman'] = df['batsman'].replace('Agarwal', 'Mayank Agarawal')
                    df['batsman'] = df['batsman'].replace('Dagar', 'Mayank Dagar')
                    df['batsman'] = df['batsman'].replace('R Sanjay Yadav', 'Sanjay Yadav')
                    df['batsman'] = df['batsman'].replace('Harshal', 'Harshal Patel')
                    df['batsman'] = df['batsman'].replace('Parag', 'Riyan Parag')
                    df['batsman'] = df['batsman'].replace('Marsh', 'Mitchell Marsh')
                    df['batsman'] = df['batsman'].replace('Patidar', 'Rajat Patidar')
                    df['batsman'] = df['batsman'].replace('Maxwell', 'Glenn Maxwell')
                    df['batsman'] = df['batsman'].replace('Domnic Muthuswami', 'Domnic Muthuswami')
                    df['batsman'] = df['batsman'].replace('Dhull', 'Yash Dhull')
                    
                    # Save the file (overwrite)
                    df.to_csv(file_path, index=False)
                    print(f"Updated: {file_path}")
                else:
                    print(f"'batsman' column not found in {file_path}")
            except Exception as e:
                print(f"Error processing {file_path}: {e}")


            # Read the CSV file
            try:
                df = pd.read_csv(file_path)
                
            # Check if 'bowler' column exists
                if 'bowler' in df.columns:
                    # Replace the name
                    df['bowler'] = df['bowler'].replace('Marlon Samuels', 'Marlon Samuels')
                    df['bowler'] = df['bowler'].replace('Gurkeerat Singh Mann', 'Gurkeerat Singh Mann')
                    df['bowler'] = df['bowler'].replace('Ahmed', 'Shahbaz Ahmed')
                    df['bowler'] = df['bowler'].replace('Green', 'Cameron Green')
                    df['bowler'] = df['bowler'].replace('Vyshak', 'Vijaykumar Vyshak')
                    df['bowler'] = df['bowler'].replace('RS Hangargekar', 'Rajvardhan Hangargekar')
                    df['bowler'] = df['bowler'].replace('Manoj Tiwary', 'Manoj Tiwary')
                    df['bowler'] = df['bowler'].replace('JPR Scantlebury-Searles', 'Javon Searles')
                    df['bowler'] = df['bowler'].replace('DJM Short', "D'Arcy Short")
                    df['bowler'] = df['bowler'].replace('Siraj', 'Mohammed Siraj')
                    df['bowler'] = df['bowler'].replace('de Grandhomme', 'Colin de Grandhomme')
                    df['bowler'] = df['bowler'].replace('R Dhawan', 'Rishi Dhawan')
                    df['bowler'] = df['bowler'].replace('Yadav', 'Mayank Yadav')
                    df['bowler'] = df['bowler'].replace('Stoinis', 'Marcus Stoinis')
                    df['bowler'] = df['bowler'].replace('Nitish Kumar', 'Nitish Kumar Reddy')
                    df['bowler'] = df['bowler'].replace('Yuvraj Singh', 'Yuvraj Singh')
                    df['bowler'] = df['bowler'].replace('Jagadeesha Suchith', 'agadeesha Suchith')
                    df['bowler'] = df['bowler'].replace('Nortje', 'Anrich Nortje')
                    df['bowler'] = df['bowler'].replace('MW Short', 'Matthew Short')
                    df['bowler'] = df['bowler'].replace('Gulbadin Naib', 'Gulbadin Naib')
                    df['bowler'] = df['bowler'].replace('Ripal Patel', 'Ripal Patel')
                    df['bowler'] = df['bowler'].replace('M Ashwin', 'Murugan Ashwin')
                    df['bowler'] = df['bowler'].replace('Wanindu Hasaranga', 'Wanindu Hasaranga')
                    df['bowler'] = df['bowler'].replace('Rahul Tripathi', 'Rahul Tripathi')
                    df['bowler'] = df['bowler'].replace('Nitish Rana', 'Nitish Rana')
                    df['bowler'] = df['bowler'].replace('Tristan Stubbs', 'Tristan Stubbs')
                    df['bowler'] = df['bowler'].replace('Sarfaraz Khan', 'Sarfaraz Khan')
                    df['bowler'] = df['bowler'].replace('Krunal', 'Krunal Pandya')
                    df['bowler'] = df['bowler'].replace('Kuldeep', 'Kuldeep Sen')
                    df['bowler'] = df['bowler'].replace('Shahrukh Khan', 'M Shahrukh Khan')
                    df['bowler'] = df['bowler'].replace('de Lange', 'Marchant de Lange')
                    df['bowler'] = df['bowler'].replace('Travis Head', 'Travis Head')
                    df['bowler'] = df['bowler'].replace('Topley', 'Reece Topley')
                    df['bowler'] = df['bowler'].replace('Siddharth', 'Siddarth Kaul')
                    df['bowler'] = df['bowler'].replace('Abdul Samad', 'Abdul Samad')
                    df['bowler'] = df['bowler'].replace('Steven Smith', 'Steven Smith')
                    df['bowler'] = df['bowler'].replace('Shubham Agarwal', 'Shubham Sanjay Agarwal')
                    df['bowler'] = df['bowler'].replace('Riyan Parag', 'Riyan Parag')
                    df['bowler'] = df['bowler'].replace('Yashasvi Jaiswal', 'Yashasvi Jaiswal')
                    df['bowler'] = df['bowler'].replace('Mustafizur', 'Mustafizur Rahman')
                    df['bowler'] = df['bowler'].replace('Suresh Raina', 'Suresh Raina')
                    df['bowler'] = df['bowler'].replace('M Nabi', 'Mohammad Nabi')
                    df['bowler'] = df['bowler'].replace('Nehal Wadhera', 'Nehal Wadhera')
                    df['bowler'] = df['bowler'].replace('Murali Vijay', 'Murali Vijay')
                    df['bowler'] = df['bowler'].replace('Hasaranga', 'Wanindu Hasaranga')
                    df['bowler'] = df['bowler'].replace('Colin Munro', 'Colin Munro')
                    df['bowler'] = df['bowler'].replace('Umran Malik', 'Umran Malik')
                    df['bowler'] = df['bowler'].replace('Ray Barman', 'Prayas Ray Barman')
                    df['bowler'] = df['bowler'].replace('Thakur', 'Yash Thakur')
                    df['bowler'] = df['bowler'].replace('Karan', 'Karn Sharma')
                    df['bowler'] = df['bowler'].replace('Aaron Finch', 'Aaron Finch')
                    df['bowler'] = df['bowler'].replace('Ayush Badoni', 'Ayush Badoni')
                    df['bowler'] = df['bowler'].replace('Shreyas Iyer', 'Shreyas Iyer')
                    df['bowler'] = df['bowler'].replace('Shivam Sharma', 'Shivam Sharma')
                    df['bowler'] = df['bowler'].replace('Dagar', 'Mayank Dagar')
                    df['bowler'] = df['bowler'].replace('Parnell', 'Wayne Parnell')
                    df['bowler'] = df['bowler'].replace('Naman Dhir', 'Naman Dhir')
                    df['bowler'] = df['bowler'].replace('Manish Pandey', 'Manish Pandey')
                    df['bowler'] = df['bowler'].replace('R Sanjay Yadav', 'Sanjay Yadav')
                    df['bowler'] = df['bowler'].replace('Rovman Powell', 'Rovman Powell')
                    df['bowler'] = df['bowler'].replace('Harshal', 'Harshal Patel')
                    df['bowler'] = df['bowler'].replace('Parthiv Patel', 'Parthiv Patel')
                    df['bowler'] = df['bowler'].replace('Rohit Sharma', 'Rohit Sharma')
                    df['bowler'] = df['bowler'].replace('Sachin Baby', 'Sachin Baby')
                    df['bowler'] = df['bowler'].replace('Sherfane Rutherford', 'Sherfane Rutherford')
                    df['bowler'] = df['bowler'].replace('Marsh', 'Mitchell Marsh')
                    df['bowler'] = df['bowler'].replace('David Warner', 'David Warner')
                    df['bowler'] = df['bowler'].replace('Maxwell', 'Glenn Maxwell')
                    df['bowler'] = df['bowler'].replace('Ramandeep Singh', 'Ramandeep Singh')
                    df['bowler'] = df['bowler'].replace('Domnic Muthuswami', 'Domnic Muthuswami')
                    df['bowler'] = df['bowler'].replace('Kane Williamson', 'Kane Williamson')
                    
                  
                    
                    # Save the file (overwrite)
                    df.to_csv(file_path, index=False)
                    print(f"Updated: {file_path}")
                else:
                    print(f"'batsman' column not found in {file_path}")
            except Exception as e:
                print(f"Error processing {file_path}: {e}")
# Out:
# Updated: dataset/2015/33b.csv
# Updated: dataset/2015/33b.csv
# Updated: dataset/2015/6a.csv
# Updated: dataset/2015/6a.csv
# Updated: dataset/2015/4b.csv
# Updated: dataset/2015/4b.csv
# Updated: dataset/2015/38b.csv
# Updated: dataset/2015/38b.csv
# Updated: dataset/2015/47a.csv
# Updated: dataset/2015/47a.csv
# Updated: dataset/2015/20a.csv
# Updated: dataset/2015/20a.csv
# Updated: dataset/2015/37a.csv
# Updated: dataset/2015/37a.csv
# Updated: dataset/2015/23a.csv
# Updated: dataset/2015/23a.csv
# Updated: dataset/2015/31a.csv
# Updated: dataset/2015/31a.csv
# Updated: dataset/2015/59a.csv
# Updated: dataset/2015/59a.csv
# Updated: dataset/2015/1b.csv
# Updated: dataset/2015/1b.csv
# Updated: dataset/2015/40a.csv
# Updated: dataset/2015/40a.csv
# Updated: dataset/2015/43a.csv
# Updated: dataset/2015/43a.csv
# Updated: dataset/2015/30b.csv
# Updated: dataset/2015/30b.csv
# Updated: dataset/2015/54a.csv
# Updated: dataset/2015/54a.csv
# Updated: dataset/2015/21b.csv
# ...
